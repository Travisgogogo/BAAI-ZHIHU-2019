# %%
import gc
import os
import time
import numpy as np
import pandas as pd
import tensorflow as tf
import warnings
warnings.filterwarnings("ignore")

import keras.backend as K
import keras.backend.tensorflow_backend as KTF
from keras.models import Sequential, Model
from keras.layers import Dense, Dropout, Activation,normalization, Input,concatenate,Dense, Embedding,Flatten
from keras.layers.advanced_activations import PReLU
from keras.callbacks import ModelCheckpoint
from keras import activations
from keras.engine.topology import Layer, InputSpec
from keras.callbacks import EarlyStopping
from sklearn.model_selection import StratifiedKFold
from keras import optimizers
from keras.utils import Sequence
from keras.layers.normalization import BatchNormalization
from keras.callbacks import Callback
from sklearn.metrics import roc_auc_score

os.environ["CUDA_VISIBLE_DEVICES"] = "1"
config = tf.ConfigProto()
config.gpu_options.allow_growth=True
sess = tf.Session(config=config)
KTF.set_session(sess)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data Loading

# %%
DATA_PATH = '../data/data_set_0926/'
FEAT_PATH = './features/'
WEIGHT_PATH = './weights/'

# %%
invite_info = pd.read_table(os.path.join(DATA_PATH, 'invite_info_0926.txt'), header=None)
invite_info.columns = ['问题ID','用户ID','邀请创建时间','邀请是否被回答']

invite_info_evaluate_A = pd.read_table(os.path.join(DATA_PATH, 'invite_info_evaluate_1_0926.txt'), header=None)
invite_info_evaluate_A.columns =  ['问题ID','用户ID','邀请创建时间']

invite_info_evaluate_B = pd.read_table(os.path.join(DATA_PATH, 'invite_info_evaluate_2_0926.txt'), header=None)
invite_info_evaluate_B.columns =  ['问题ID','用户ID','邀请创建时间']

oversample = False

if oversample:
    data = pd.concat([invite_info, invite_info_evaluate_B, invite_info_evaluate_A], axis=0)
else:
    data = pd.concat([invite_info, invite_info_evaluate_B], axis=0)
# Out:
# 14

# %% [markdown]
# # Feature Engineering

# %%
tic = time.time()
tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'ques_describe_W_sum_64.h5'), key='data')
data = data.merge(tmp, on='问题ID', how='left')

tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'ques_describe_SW_sum_64.h5'), key='data')
data = data.merge(tmp, on='问题ID', how='left')

tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'ques_topic_W_sum_64.h5'), key='data')
data = data.merge(tmp, on='问题ID', how='left')

tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'ques_topic_SW_sum_64.h5'), key='data')
data = data.merge(tmp, on='问题ID', how='left')

tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'user_watched_topic_w2v_sum_64.h5'), key='data')
data = data.merge(tmp, on='用户ID', how='left')

tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'user_fav_topic_w2v_sum_64.h5'), key='data')
data = data.merge(tmp, on='用户ID', how='left')

tmp = pd.read_hdf(os.path.join(FEAT_PATH, 'ques_attach_topic_w2v_sum_64.h5'), key='data')
data = data.merge(tmp, on='问题ID', how='left')

print("Used time: %d s" % (time.time()-tic))
# Out:
# CPU times: user 2min 43s, sys: 1min 58s, total: 4min 41s
# Wall time: 4min 54s

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    tic = time.time()
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))

    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    toc = time.time()
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    print('Used time: %d s'%(toc-tic))
    return df

# %%
data = reduce_mem_usage(data)
# Out:
# Memory usage of dataframe is 36741.55 MB
# Memory usage after optimization is: 9385.92 MB
# Decreased by 74.5%
# Used time: 1258 s

# %%
del tmp
gc.collect()
# Out:
# 14

# %% [markdown]
# # Model

# %%
ques_describe_W_feat = ['ques_describe_W_w2v_sum_{}'.format(i) for i in range(1,65)]
ques_describe_SW_feat = ['ques_describe_SW_w2v_sum_{}'.format(i) for i in range(1,65)]
ques_topic_W_feat = ['ques_topic_W_w2v_sum_{}'.format(i) for i in range(1,65)]
ques_topic_SW_feat = ['SW_w2v_sum_{}'.format(i) for i in range(1,65)]
user_watched_topic_feat = ['用户关注的话题_w2v_sum_{}'.format(i) for i in range(1,65)]
user_fav_topic_feat = ['用户感兴趣的话题_w2v_sum_{}'.format(i) for i in range(1,65)]
ques_attach_topic_feat = ['问题绑定的话题ID_w2v_sum_{}'.format(i) for i in range(1,65)]

num_feat =  ques_describe_W_feat + ques_describe_SW_feat +  ques_topic_W_feat + ques_topic_SW_feat + user_watched_topic_feat +\
            user_fav_topic_feat + ques_attach_topic_feat

# %%
feature = num_feat

test_index = np.isnan(data['邀请是否被回答'])
train_index = ~test_index
train_x = data[train_index][feature].reset_index(drop=True)
train_y = data[train_index]['邀请是否被回答'].reset_index(drop=True)
test_x  = data[test_index][feature].reset_index(drop=True)
print('All features: train shape {}, test shape {}'.format(train_x.shape, test_x.shape))
# Out:
# All features: train shape (9489162, 448), test shape (1141718, 448)

# %%
del data
gc.collect()
# Out:
# 28

# %%
class DataSequence(Sequence):
    
    def __init__(self, x, y, single_embed_feat, dense_feat, batch_size=128):
        self.x = x
        self.y = y
        self.single_embed_feat = single_embed_feat
        self.num_feat = num_feat
        self.batch_size = batch_size
        self.x_single_embed = [x[f].values for f in single_embed_feat]
        self.x_dense = x[dense_feat].values
        
    def __len__(self):
        return int(np.ceil(len(self.x) / float(self.batch_size)))
    
    def __getitem__(self, idx):
        batch_x = [xf[idx * self.batch_size:(idx + 1) * self.batch_size] for xf in self.x_single_embed] \
                + [self.x_dense[idx * self.batch_size:(idx + 1) * self.batch_size]]
        batch_y = self.y[idx * self.batch_size:(idx + 1) * self.batch_size]
        return batch_x, batch_y

# %%
class MetricsCallback(Callback):
    def __init__(self, trn_x, y_trn,val_x, y_val, batch_size=128, save_name='weight.h5'):
        self.trn_generator = DataSequence(trn_x, y_trn, [], num_feat, batch_size=batch_size)
        self.val_generator = DataSequence(val_x, y_val, [], num_feat, batch_size=batch_size)
        self.y_trn = y_trn
        self.y_val = y_val
        self.save_name = save_name
        self.best_score = 0.5

    def on_epoch_end(self, epoch, logs={}):
        # train
        y_pred = self.model.predict_generator(self.trn_generator, 
                                              max_queue_size=10, 
                                              workers=1, 
                                              use_multiprocessing=False, 
                                              verbose=0)
        roc = roc_auc_score(self.y_trn, y_pred)
        # valid
        y_pred_val = self.model.predict_generator(self.val_generator, 
                                              max_queue_size=10, 
                                              workers=1, 
                                              use_multiprocessing=False, 
                                              verbose=0)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')

        if roc_val > self.best_score:
            self.best_score = roc_val
            self.model.save_weights(os.path.join(WEIGHT_PATH, self.save_name))
        
        return

# %%
def DNN():
    
    input1  = Input(shape=(X_train.shape[1],))
    dense_1 = Dense(512)(input1)
    dense_1 = BatchNormalization()(dense_1)
    dense_1 = PReLU()(dense_1)
    dense_2 = Dense(256)(dense_1)
    dense_2 = BatchNormalization()(dense_2)
    dense_2 = PReLU()(dense_2)
    dense_3 = Dense(128)(dense_2)
    dense_3 = BatchNormalization()(dense_3)
    dense_3 = PReLU()(dense_3)
    dense_4 = Dense(64)(dense_3)
    dense_4 = BatchNormalization()(dense_4)
    dense_4 = PReLU()(dense_4)

    out     = Dense(1, activation='sigmoid')(dense_4)
    model = Model(inputs=input1, outputs = out)

    return model

# %%
##Train
BATCH_SIZE = 1024

for i, seeds in enumerate([42]):
    kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=seeds)
    for index, (tr_idx, va_idx) in enumerate(kfold.split(train_x, train_y.values)):
        print('*' * 30)
        X_train, y_train, X_valid, y_valid = train_x.iloc[tr_idx], train_y[tr_idx], train_x.iloc[va_idx], train_y[va_idx]
        trn_generator = DataSequence(X_train, y_train, [], num_feat, batch_size=BATCH_SIZE)
        val_generator = DataSequence(X_valid, y_valid, [], num_feat, batch_size=BATCH_SIZE)
        model = DNN()
        model.compile(loss ='binary_crossentropy', optimizer='Adam')
        history = model.fit_generator(generator=trn_generator,
                                      validation_data=val_generator,
                                      epochs=20, 
                                      verbose=1, 
                                      callbacks=[MetricsCallback(X_train, y_train,X_valid, y_valid, 
                                                 batch_size=BATCH_SIZE*4, save_name='mlp_fold_%d.h5' % index)],
                                      max_queue_size=10, 
                                      workers=1, 
                                      use_multiprocessing=False)  #0.6830
        
        del X_train, y_train, X_valid, y_valid
        gc.collect()
# Out:
# ******************************
# Epoch 1/20
# 742/742 [==============================] - 89s 119ms/step - loss: 0.4585 - val_loss: 0.4440
# roc-auc: 0.6608 - roc-auc_val: 0.6578
# Epoch 2/20
# 742/742 [==============================] - 90s 122ms/step - loss: 0.4455 - val_loss: 0.4403
# roc-auc: 0.6737 - roc-auc_val: 0.6682
# Epoch 3/20
# 742/742 [==============================] - 90s 122ms/step - loss: 0.4417 - val_loss: 0.4388
# roc-auc: 0.6819 - roc-auc_val: 0.6733
# Epoch 4/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4391 - val_loss: 0.4375
# roc-auc: 0.6887 - roc-auc_val: 0.6771
# Epoch 5/20
# 742/742 [==============================] - 91s 122ms/step - loss: 0.4369 - val_loss: 0.4364
# roc-auc: 0.6958 - roc-auc_val: 0.6804
# Epoch 6/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4350 - val_loss: 0.4354
# roc-auc: 0.7 - roc-auc_val: 0.682
# Epoch 7/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4332 - val_loss: 0.4346
# roc-auc: 0.7066 - roc-auc_val: 0.6846
# Epoch 8/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4315 - val_loss: 0.4341
# roc-auc: 0.7116 - roc-auc_val: 0.6862
# Epoch 9/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4299 - val_loss: 0.4333
# roc-auc: 0.717 - roc-auc_val: 0.6882
# Epoch 10/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4284 - val_loss: 0.4331
# roc-auc: 0.7232 - roc-auc_val: 0.689
# Epoch 11/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4269 - val_loss: 0.4326
# roc-auc: 0.7285 - roc-auc_val: 0.6905
# Epoch 12/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4256 - val_loss: 0.4318
# roc-auc: 0.7323 - roc-auc_val: 0.6925
# Epoch 13/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4242 - val_loss: 0.4318
# roc-auc: 0.7375 - roc-auc_val: 0.6927
# Epoch 14/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4230 - val_loss: 0.4316
# roc-auc: 0.742 - roc-auc_val: 0.6931
# Epoch 15/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4218 - val_loss: 0.4310
# roc-auc: 0.7448 - roc-auc_val: 0.6952
# Epoch 16/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4208 - val_loss: 0.4313
# roc-auc: 0.75 - roc-auc_val: 0.6943
# Epoch 17/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4197 - val_loss: 0.4310
# roc-auc: 0.7522 - roc-auc_val: 0.696
# Epoch 18/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4187 - val_loss: 0.4307
# roc-auc: 0.7567 - roc-auc_val: 0.6965
# Epoch 19/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4177 - val_loss: 0.4309
# roc-auc: 0.7597 - roc-auc_val: 0.6956
# Epoch 20/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4168 - val_loss: 0.4314
# roc-auc: 0.7611 - roc-auc_val: 0.6965
# ******************************
# Epoch 1/20
# 742/742 [==============================] - 85s 114ms/step - loss: 0.4682 - val_loss: 0.4430
# roc-auc: 0.6627 - roc-auc_val: 0.6599
# Epoch 2/20
# 742/742 [==============================] - 76s 102ms/step - loss: 0.4457 - val_loss: 0.4405
# roc-auc: 0.6725 - roc-auc_val: 0.6667
# Epoch 3/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4421 - val_loss: 0.4389
# roc-auc: 0.6819 - roc-auc_val: 0.6732
# Epoch 4/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4394 - val_loss: 0.4371
# roc-auc: 0.6894 - roc-auc_val: 0.6773
# Epoch 5/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4371 - val_loss: 0.4362
# roc-auc: 0.6968 - roc-auc_val: 0.6805
# Epoch 6/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4351 - val_loss: 0.4353
# roc-auc: 0.7025 - roc-auc_val: 0.6827
# Epoch 7/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4332 - val_loss: 0.4346
# roc-auc: 0.7077 - roc-auc_val: 0.6848
# Epoch 8/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4314 - val_loss: 0.4338
# roc-auc: 0.7131 - roc-auc_val: 0.6866
# Epoch 9/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4298 - val_loss: 0.4333
# roc-auc: 0.7188 - roc-auc_val: 0.6878
# Epoch 10/20
# 742/742 [==============================] - 75s 100ms/step - loss: 0.4282 - val_loss: 0.4327
# roc-auc: 0.7233 - roc-auc_val: 0.6897
# Epoch 11/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4268 - val_loss: 0.4321
# roc-auc: 0.7297 - roc-auc_val: 0.691
# Epoch 12/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4255 - val_loss: 0.4320
# roc-auc: 0.7331 - roc-auc_val: 0.6916
# Epoch 13/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4242 - val_loss: 0.4318
# roc-auc: 0.7378 - roc-auc_val: 0.6924
# Epoch 14/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4230 - val_loss: 0.4313
# roc-auc: 0.743 - roc-auc_val: 0.6935
# Epoch 15/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4219 - val_loss: 0.4314
# roc-auc: 0.7458 - roc-auc_val: 0.6938
# Epoch 16/20
# 742/742 [==============================] - 76s 102ms/step - loss: 0.4207 - val_loss: 0.4314
# roc-auc: 0.7487 - roc-auc_val: 0.6934
# Epoch 17/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4198 - val_loss: 0.4312
# roc-auc: 0.753 - roc-auc_val: 0.6942
# Epoch 18/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4188 - val_loss: 0.4310
# roc-auc: 0.7572 - roc-auc_val: 0.6953
# Epoch 19/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4178 - val_loss: 0.4315
# roc-auc: 0.7571 - roc-auc_val: 0.6971
# Epoch 20/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4169 - val_loss: 0.4309
# roc-auc: 0.7624 - roc-auc_val: 0.696
# ******************************
# Epoch 1/20
# 742/742 [==============================] - 100s 134ms/step - loss: 0.4627 - val_loss: 0.4438
# roc-auc: 0.6619 - roc-auc_val: 0.6595
# Epoch 2/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4465 - val_loss: 0.4410
# roc-auc: 0.6732 - roc-auc_val: 0.6686
# Epoch 3/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4420 - val_loss: 0.4391
# roc-auc: 0.6807 - roc-auc_val: 0.673
# Epoch 4/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4393 - val_loss: 0.4374
# roc-auc: 0.6878 - roc-auc_val: 0.6769
# Epoch 5/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4370 - val_loss: 0.4371
# roc-auc: 0.6945 - roc-auc_val: 0.6799
# Epoch 6/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4351 - val_loss: 0.4354
# roc-auc: 0.7025 - roc-auc_val: 0.6836
# Epoch 7/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4333 - val_loss: 0.4346
# roc-auc: 0.7068 - roc-auc_val: 0.6847
# Epoch 8/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4315 - val_loss: 0.4340
# roc-auc: 0.7121 - roc-auc_val: 0.6868
# Epoch 9/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4299 - val_loss: 0.4333
# roc-auc: 0.7172 - roc-auc_val: 0.6885
# Epoch 10/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4284 - val_loss: 0.4328
# roc-auc: 0.7238 - roc-auc_val: 0.6899
# Epoch 11/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4269 - val_loss: 0.4322
# roc-auc: 0.7279 - roc-auc_val: 0.6916
# Epoch 12/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4255 - val_loss: 0.4323
# roc-auc: 0.7322 - roc-auc_val: 0.6917
# Epoch 13/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4243 - val_loss: 0.4314
# roc-auc: 0.7381 - roc-auc_val: 0.6934
# Epoch 14/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4230 - val_loss: 0.4315
# roc-auc: 0.7424 - roc-auc_val: 0.694
# Epoch 15/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4218 - val_loss: 0.4311
# roc-auc: 0.7462 - roc-auc_val: 0.6942
# Epoch 16/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4206 - val_loss: 0.4307
# roc-auc: 0.7489 - roc-auc_val: 0.6958
# Epoch 17/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4196 - val_loss: 0.4309
# roc-auc: 0.7521 - roc-auc_val: 0.6954
# Epoch 18/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4186 - val_loss: 0.4315
# roc-auc: 0.7562 - roc-auc_val: 0.6942
# Epoch 19/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4177 - val_loss: 0.4311
# roc-auc: 0.7594 - roc-auc_val: 0.6953
# Epoch 20/20
# 742/742 [==============================] - 91s 122ms/step - loss: 0.4168 - val_loss: 0.4313
# roc-auc: 0.7623 - roc-auc_val: 0.6958
# ******************************
# Epoch 1/20
# 742/742 [==============================] - 99s 134ms/step - loss: 0.4603 - val_loss: 0.4435
# roc-auc: 0.6624 - roc-auc_val: 0.6595
# Epoch 2/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4458 - val_loss: 0.4406
# roc-auc: 0.674 - roc-auc_val: 0.6679
# Epoch 3/20
# 742/742 [==============================] - 90s 122ms/step - loss: 0.4422 - val_loss: 0.4387
# roc-auc: 0.6819 - roc-auc_val: 0.673
# Epoch 4/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4394 - val_loss: 0.4379
# roc-auc: 0.688 - roc-auc_val: 0.6758
# Epoch 5/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4372 - val_loss: 0.4366
# roc-auc: 0.6944 - roc-auc_val: 0.6793
# Epoch 6/20
# 742/742 [==============================] - 91s 122ms/step - loss: 0.4351 - val_loss: 0.4355
# roc-auc: 0.7003 - roc-auc_val: 0.6818
# Epoch 7/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4334 - val_loss: 0.4344
# roc-auc: 0.7069 - roc-auc_val: 0.6849
# Epoch 8/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4316 - val_loss: 0.4340
# roc-auc: 0.7125 - roc-auc_val: 0.6861
# Epoch 9/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4301 - val_loss: 0.4337
# roc-auc: 0.7175 - roc-auc_val: 0.688
# Epoch 10/20
# 742/742 [==============================] - 92s 123ms/step - loss: 0.4285 - val_loss: 0.4332
# roc-auc: 0.7231 - roc-auc_val: 0.6888
# Epoch 11/20
# 742/742 [==============================] - 90s 122ms/step - loss: 0.4271 - val_loss: 0.4325
# roc-auc: 0.7276 - roc-auc_val: 0.6908
# Epoch 12/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4257 - val_loss: 0.4324
# roc-auc: 0.7318 - roc-auc_val: 0.691
# Epoch 13/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4244 - val_loss: 0.4322
# roc-auc: 0.7375 - roc-auc_val: 0.6921
# Epoch 14/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4232 - val_loss: 0.4315
# roc-auc: 0.7409 - roc-auc_val: 0.6936
# Epoch 15/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4221 - val_loss: 0.4314
# roc-auc: 0.7444 - roc-auc_val: 0.6935
# Epoch 16/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4210 - val_loss: 0.4312
# roc-auc: 0.7496 - roc-auc_val: 0.6942
# Epoch 17/20
# 742/742 [==============================] - 92s 125ms/step - loss: 0.4198 - val_loss: 0.4316
# roc-auc: 0.7512 - roc-auc_val: 0.6937
# Epoch 18/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4188 - val_loss: 0.4307
# roc-auc: 0.756 - roc-auc_val: 0.6958
# Epoch 19/20
# 742/742 [==============================] - 91s 123ms/step - loss: 0.4179 - val_loss: 0.4309
# roc-auc: 0.7588 - roc-auc_val: 0.6958
# Epoch 20/20
# 742/742 [==============================] - 92s 124ms/step - loss: 0.4170 - val_loss: 0.4307
# roc-auc: 0.7622 - roc-auc_val: 0.6968
# ******************************
# Epoch 1/20
# 742/742 [==============================] - 81s 109ms/step - loss: 0.4555 - val_loss: 0.4437
# roc-auc: 0.6625 - roc-auc_val: 0.6594
# Epoch 2/20
# 742/742 [==============================] - 75s 100ms/step - loss: 0.4446 - val_loss: 0.4405
# roc-auc: 0.6736 - roc-auc_val: 0.6678
# Epoch 3/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4412 - val_loss: 0.4388
# roc-auc: 0.6807 - roc-auc_val: 0.6725
# Epoch 4/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4387 - val_loss: 0.4380
# roc-auc: 0.6871 - roc-auc_val: 0.6755
# Epoch 5/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4366 - val_loss: 0.4363
# roc-auc: 0.695 - roc-auc_val: 0.6796
# Epoch 6/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4347 - val_loss: 0.4355
# roc-auc: 0.7006 - roc-auc_val: 0.6824
# Epoch 7/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4329 - val_loss: 0.4346
# roc-auc: 0.7065 - roc-auc_val: 0.6848
# Epoch 8/20
# 742/742 [==============================] - 76s 102ms/step - loss: 0.4313 - val_loss: 0.4336
# roc-auc: 0.7128 - roc-auc_val: 0.6872
# Epoch 9/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4297 - val_loss: 0.4335
# roc-auc: 0.7174 - roc-auc_val: 0.6878
# Epoch 10/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4282 - val_loss: 0.4326
# roc-auc: 0.7241 - roc-auc_val: 0.6903
# Epoch 11/20
# 742/742 [==============================] - 76s 102ms/step - loss: 0.4267 - val_loss: 0.4322
# roc-auc: 0.7293 - roc-auc_val: 0.6914
# Epoch 12/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4253 - val_loss: 0.4320
# roc-auc: 0.7336 - roc-auc_val: 0.6923
# Epoch 13/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4241 - val_loss: 0.4316
# roc-auc: 0.739 - roc-auc_val: 0.693
# Epoch 14/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4229 - val_loss: 0.4315
# roc-auc: 0.7425 - roc-auc_val: 0.6939
# Epoch 15/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4217 - val_loss: 0.4314
# roc-auc: 0.7462 - roc-auc_val: 0.6947
# Epoch 16/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4205 - val_loss: 0.4311
# roc-auc: 0.75 - roc-auc_val: 0.6945
# Epoch 17/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4196 - val_loss: 0.4315
# roc-auc: 0.7519 - roc-auc_val: 0.6951
# Epoch 18/20
# 742/742 [==============================] - 75s 102ms/step - loss: 0.4186 - val_loss: 0.4313
# roc-auc: 0.7559 - roc-auc_val: 0.6959
# Epoch 19/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4176 - val_loss: 0.4316
# roc-auc: 0.7588 - roc-auc_val: 0.6966
# Epoch 20/20
# 742/742 [==============================] - 75s 101ms/step - loss: 0.4167 - val_loss: 0.4309
# roc-auc: 0.7626 - roc-auc_val: 0.6966

# %%
##valid & Test
BATCH_SIZE = 1024

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
test_generator = DataSequence(test_x, np.zeros(test_x.shape[0]), [], num_feat, batch_size=BATCH_SIZE)

stack_test = np.zeros((test_x.shape[0], 1))
stack_train = np.zeros((train_x.shape[0], 1))

for i, (tr_idx, va_idx) in enumerate(kfold.split(train_x, train_y.values)):
    print('-'*100)
    print('Fold %d' % i)
    X_train, y_train, X_valid, y_valid = train_x.iloc[tr_idx], train_y[tr_idx], train_x.iloc[va_idx], train_y[va_idx]

    K.clear_session()
    model = DNN()
    model.compile(loss='binary_crossentropy', optimizer='adam',)

    val_generator = DataSequence(X_valid, y_valid, [], num_feat, batch_size=BATCH_SIZE)

    model.load_weights(os.path.join(WEIGHT_PATH, 'mlp_fold_%d.h5' % i))

    stack_train[va_idx] = model.predict_generator(val_generator, verbose=1)
    stack_test += model.predict_generator(test_generator, verbose=1) / 5
    
    print(roc_auc_score(y_valid, stack_train[va_idx]))
    
    del X_train, y_train, X_valid, y_valid
    gc.collect()
    print('Predict Done.')
# Out:
# ----------------------------------------------------------------------------------------------------
# Fold 0
# 1854/1854 [==============================] - 16s 9ms/step
# 1115/1115 [==============================] - 9s 8ms/step
# 0.6831091556916525
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 1
# 1854/1854 [==============================] - 15s 8ms/step
# 1115/1115 [==============================] - 9s 8ms/step
# 0.6832178829122443
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 2
# 1854/1854 [==============================] - 15s 8ms/step
# 1115/1115 [==============================] - 9s 8ms/step
# 0.6833419535485171
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 3
# 1854/1854 [==============================] - 15s 8ms/step
# 1115/1115 [==============================] - 9s 8ms/step
# 0.6828106345053794
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 4
# 1854/1854 [==============================] - 15s 8ms/step
# 1115/1115 [==============================] - 9s 8ms/step
# 0.6820476438130859
# Predict Done.

# %%
stack = np.vstack([stack_train, stack_test])
df_stack = pd.DataFrame()
df_stack['w2v_sum_nn'] = stack[:,0]

# %%
df_stack.to_pickle(os.path.join(FEAT_PATH, 'w2v_sum_nn.pkl'))
print("Feature saved, shape:",df_stack.shape)
# Out:
# Feature saved, shape: (10630880, 1)
